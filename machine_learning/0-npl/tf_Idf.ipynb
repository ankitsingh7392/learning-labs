# %%
# pip install scikit-learn

# %%
documents = [
    "data science is fun",
    "data is powerful",
    "machine learning is fun"
]

# %%
documents
# Out:
# ['data science is fun', 'data is powerful', 'machine learning is fun']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [
    "data science is fun",
    "data is powerful",
    "machine learning is fun"
]

# Create TF-IDF model
vectorizer = TfidfVectorizer()

# Fit and transform data
tfidf_matrix = vectorizer.fit_transform(documents)

# %%
feature_name = vectorizer.get_feature_names_out()

# %%
tfidf_matrix.toarray()
# Out:
# array([[0.4804584 , 0.4804584 , 0.37311881, 0.        , 0.        ,
#         0.        , 0.63174505],
#        [0.54783215, 0.        , 0.42544054, 0.        , 0.        ,
#         0.72033345, 0.        ],
#        [0.        , 0.44451431, 0.34520502, 0.5844829 , 0.5844829 ,
#         0.        , 0.        ]])
