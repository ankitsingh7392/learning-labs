# %% [markdown]
# # What is Word2Vec?
#
# **Word2Vec** is a technique that turns words into vectors (numbers) so that:
#
# * **Similar words** -> similar vectors
# * **Relationships are preserved** * *Example:* `king - man + woman ≈ queen`
#
# This overall concept is known as **word embeddings**.

# %% [markdown]
# ## Two Architectures (core idea)

# %% [markdown]
# 1. CBOW (Continuous Bag of Words)
# 2. Skip-gram (more powerful)

# %% [markdown]
# ### Example: CBOW (Continuous Bag of Words)
# Predict target word from context
#
# ```text
# "The cat sits on the mat"
# Context: ["The", "cat", "on", "the"]
# Target: "sits"
# ```

# %% [markdown]
# #### Example: Skip-gram (more powerful)
#
# Target: "sits"
# Predict: ["The", "cat", "on", "the"]

# %%
print("hello")
# Out:
# hello

# %%
from gensim.models import Word2Vec

sentences = [
    ["king", "is", "a", "strong", "man"],
    ["queen", "is", "a", "wise", "woman"],
    ["boy", "is", "a", "young", "man"],
    ["girl", "is", "a", "young", "woman"],
    ["prince", "is", "a", "young", "king"],
    ["princess", "is", "a", "young", "queen"]
]

model = Word2Vec(sentences, vector_size=50, window=2, min_count=1, sg=1)

# %%
print(model.wv["king"])
# Out:
# [-0.0164887   0.01860078 -0.00039382 -0.00393301  0.00921003 -0.00819287
#   0.00548681  0.01388243  0.01213075 -0.01502416  0.01876565  0.0093417
#   0.0079311  -0.01248553  0.01692189 -0.00429838  0.01765338 -0.01072234
#  -0.01626082  0.01364972  0.00334333 -0.00439857  0.01903062  0.0189858
#  -0.01954713  0.00501162  0.01231259  0.00774671  0.00404528  0.00086295
#   0.0013502  -0.00764289 -0.01428142 -0.00417957  0.00784935  0.01763907
#   0.01852128 -0.01195079 -0.01880363  0.01953256  0.00686217  0.01033083
#   0.01256277 -0.00560892  0.01464531  0.00566319  0.00574406 -0.00476152
#  -0.0062564  -0.00474001]
